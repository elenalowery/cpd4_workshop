# %%
import itc_utils.flight_service as itcfs

readClient = itcfs.get_flight_client()

nb_data_request = {
    'data_name': """Customer_Transaction_Master.csv""",
    'interaction_properties': {
    }
}

flightInfo = itcfs.get_flight_info(readClient, nb_data_request=nb_data_request)

data_df_1 = itcfs.read_pandas_and_concat(readClient, flightInfo)
data_df_1.head(10)
# Out:
#   CUST_ID TRANSACTION_ID PRODUCT_ID  \
# 0     487          30044       3177
# 1     626           1766       3178
# 2     719          30033       3179
# 3     113           1222       3180
# 4     118          12986       3181
# 5     636          25615       3182
# 6     714          28572       3183
# 7     642          22265       3184
# 8     458          19729       3185
# 9      20          22863       3186
#
#                                     ITEM_NAME     LINE CATEGORY  \
# 0               Anastasia Beverly Hills Dress  Clothes  Clothes
# 1                   Guess Fit and Flair Dress  Clothes  Clothes
# 2                      Bar III Cropped Jacket  Clothes  Clothes
# 3                Anne Klein Fayza Dress Shoes  Clothes  Clothes
# 4                 Anne Klein Barb Dress Shoes  Clothes  Clothes
# 5          Calvin Klein Gayle High Heel Shoes  Clothes  Clothes
# 6      Calvin Klein Catherine High Heel Shoes  Clothes  Clothes
# 7            Calvin Klein Zipper Sheath Dress  Clothes  Clothes
# 8  Calvin Klein Sleevess Belted Striped Dress  Clothes  Clothes
# 9       Calvin Klein Horseshoe Neckline Dress  Clothes  Clothes
#
#   NUMBER_OF_ITEMS     RRP TOTAL_AMOUNT TRANSACTION_TIME
# 0               1  639.99       639.99        11/1/2010
# 1               1  539.99       539.99        11/1/2010
# 2               1  299.99       299.99        11/1/2010
# 3               1  779.99       779.99        11/1/2010
# 4               1  399.99       399.99        11/1/2010
# 5               1  399.99       399.99        11/1/2010
# 6               1  449.99       449.99        11/1/2010
# 7               1  999.99       999.99        11/1/2010
# 8               1  639.99       639.99        11/1/2010
# 9               3  239.99       719.97        11/1/2010

# %%
readClient = itcfs.get_flight_client()

nb_data_request = {
    'data_name': """Mortgage_Data_Merged.csv""",
    'interaction_properties': {
    }
}

flightInfo = itcfs.get_flight_info(readClient, nb_data_request=nb_data_request)

data_df_2 = itcfs.read_pandas_and_concat(readClient, flightInfo)
data_df_2.head(10)
